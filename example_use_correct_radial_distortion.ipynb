# %%
import sys
sys.path.append('/home/jstark/project-jstark/lib')
import correct_radial_distortion
# Out:
# /sw/apps/python3/3.6.5/lib/python3.6/site-packages/tifffile/tifffile.py:7685: UserWarning: No module named 'tifffile._tifffile'
#   Functionality might be degraded or be slow.
#
#   warnings.warn('%s%s' % (e, warn))

# %%
x_single, y_inverse_single = correct_radial_distortion.inverse_method('z168400.tif')
x_single, y_hybrid_single = correct_radial_distortion.hybrid_method('z168400.tif')

# %%
correct_radial_distortion.show_images(x_single, y_hybrid_single)

# %%
x_stack, y_inverse_stack = correct_radial_distortion.inverse_method('Locations/Location_1/volumes/vol_28.tif')
x_stack, y_hybrid_stack = correct_radial_distortion.hybrid_method('Locations/Location_1/volumes/vol_28.tif')

# %%
correct_radial_distortion.show_frames(x_stack, y_hybrid_stack, 10)

# %%
# %%time
x_stack, y_inverse_stack = correct_radial_distortion.inverse_method('Locations/Location_1/volumes/vol_28.tif')
# Out:
# CPU times: user 8.31 s, sys: 55 ms, total: 8.37 s
# Wall time: 8.48 s

# %%
# %%time
x_stack, y_hybrid_stack = correct_radial_distortion.hybrid_method('Locations/Location_1/volumes/vol_28.tif')
# Out:
# CPU times: user 10.8 s, sys: 14.8 ms, total: 10.8 s
# Wall time: 10.8 s
