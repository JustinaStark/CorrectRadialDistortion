# %%
import sys
sys.path.append('lib')
from correct_radial_distortion_new import Correction
# Out:
# /sw/apps/python3/3.6.5/lib/python3.6/site-packages/tifffile/tifffile.py:7685: UserWarning: No module named 'tifffile._tifffile'
#   Functionality might be degraded or be slow.
#
#   warnings.warn('%s%s' % (e, warn))

# %%
correction_z168400 = Correction('z168400.tif')

# %%
show_images = correction_z168400.show_images
show_frames = correction_z168400.show_frames

# %%
input_z168400, output_z168400 = correction_z168400.hybrid_method()
# Out:
# /sw/apps/python3/3.6.5/lib/python3.6/site-packages/scipy/interpolate/_fitpack_impl.py:974: RuntimeWarning: The maximal number of iterations (20) allowed for finding smoothing
# spline with fp=s has been reached. Probable cause: s too small.
# (abs(fp-s)/s>0.001)
# 	kx,ky=1,1 nx,ny=4,5 m=6 fp=2.552476 s=2.535898
#   warnings.warn(RuntimeWarning(_iermess2[ierm][0] + _mess))
# /sw/apps/python3/3.6.5/lib/python3.6/site-packages/scipy/interpolate/_fitpack_impl.py:974: RuntimeWarning: The maximal number of iterations (20) allowed for finding smoothing
# spline with fp=s has been reached. Probable cause: s too small.
# (abs(fp-s)/s>0.001)
# 	kx,ky=1,1 nx,ny=5,5 m=6 fp=2.538545 s=2.535898
#   warnings.warn(RuntimeWarning(_iermess2[ierm][0] + _mess))

# %%
show_images(input_z168400, output_z168400)

# %%
correction_beads = Correction('beads_y19828.tif')

# %%
input_beads, output_beads = correction_beads.hybrid_method()

# %%
show_images(input_beads, output_beads)

# %%
correction_volume_loaction1 = Correction('vol_28.tif')

# %%
input_vol28, output_vol28 = correction_volume_loaction1.hybrid_method()
# Out:
# /sw/apps/python3/3.6.5/lib/python3.6/site-packages/scipy/interpolate/_fitpack_impl.py:974: RuntimeWarning: The maximal number of iterations (20) allowed for finding smoothing
# spline with fp=s has been reached. Probable cause: s too small.
# (abs(fp-s)/s>0.001)
# 	kx,ky=1,1 nx,ny=4,5 m=6 fp=2.552476 s=2.535898
#   warnings.warn(RuntimeWarning(_iermess2[ierm][0] + _mess))
# /sw/apps/python3/3.6.5/lib/python3.6/site-packages/scipy/interpolate/_fitpack_impl.py:974: RuntimeWarning: The maximal number of iterations (20) allowed for finding smoothing
# spline with fp=s has been reached. Probable cause: s too small.
# (abs(fp-s)/s>0.001)
# 	kx,ky=1,1 nx,ny=5,5 m=6 fp=2.538545 s=2.535898
#   warnings.warn(RuntimeWarning(_iermess2[ierm][0] + _mess))
# /sw/apps/python3/3.6.5/lib/python3.6/site-packages/scipy/interpolate/_fitpack_impl.py:974: RuntimeWarning: The maximal number of iterations (20) allowed for finding smoothing
# spline with fp=s has been reached. Probable cause: s too small.
# ...

# %%
show_frames(input_vol28, output_vol28, 10)
